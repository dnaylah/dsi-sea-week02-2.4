# %% [markdown]
# # Lab 2.2.4

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./assets/datasets/billboard.csv")
dd = pd.read_csv("./assets/datasets/billboard.csv")

# %%
#dropping the columns with all rows consisting of nan
df = df.dropna(axis=1,how="all")
df.columns
# Out:
# Index([u'year', u'artist.inverted', u'track', u'time', u'genre',
#        u'date.entered', u'date.peaked', u'x1st.week', u'x2nd.week',
#        u'x3rd.week', u'x4th.week', u'x5th.week', u'x6th.week', u'x7th.week',
#        u'x8th.week', u'x9th.week', u'x10th.week', u'x11th.week', u'x12th.week',
#        u'x13th.week', u'x14th.week', u'x15th.week', u'x16th.week',
#        u'x17th.week', u'x18th.week', u'x19th.week', u'x20th.week',
#        u'x21st.week', u'x22nd.week', u'x23rd.week', u'x24th.week',
#        u'x25th.week', u'x26th.week', u'x27th.week', u'x28th.week',
#        u'x29th.week', u'x30th.week', u'x31st.week', u'x32nd.week',
#        u'x33rd.week', u'x34th.week', u'x35th.week', u'x36th.week',
#        u'x37th.week', u'x38th.week', u'x39th.week', u'x40th.week',
#        u'x41st.week', u'x42nd.week', u'x43rd.week', u'x44th.week',
#        u'x45th.week', u'x46th.week', u'x47th.week', u'x48th.week',
#        u'x49th.week', u'x50th.week', u'x51st.week', u'x52nd.week',
# ...

# %%
#some stats including mean, min/max, standard deviation, and quartiles
df.describe()
# Out:
#          year   x1st.week   x2nd.week   x3rd.week   x4th.week   x5th.week  \
# count   317.0  317.000000  312.000000  307.000000  300.000000  292.000000
# mean   2000.0   79.958991   71.173077   65.045603   59.763333   56.339041
# std       0.0   14.686865   18.200443   20.752302   22.324619   23.780022
# min    2000.0   15.000000    8.000000    6.000000    5.000000    2.000000
# 25%    2000.0   74.000000   63.000000   53.000000   44.750000   38.750000
# 50%    2000.0   81.000000   73.000000   66.000000   61.000000   57.000000
# 75%    2000.0   91.000000   84.000000   79.000000   76.000000   73.250000
# max    2000.0  100.000000  100.000000  100.000000  100.000000  100.000000
#
#         x6th.week   x7th.week   x8th.week   x9th.week     ...      x56th.week  \
# count  280.000000  269.000000  260.000000  253.000000     ...        2.000000
# mean    52.360714   49.219331   47.119231   46.343874     ...       25.500000
# ...

# %%
#variance for each column
np.var(df)
# Out:
# year             0.000000
# x1st.week      215.023555
# x2nd.week      330.194403
# x3rd.week      429.255249
# x4th.week      496.727322
# x5th.week      563.552859
# x6th.week      596.802028
# x7th.week      655.695388
# x8th.week      692.743476
# x9th.week      733.474636
# x10th.week     789.307041
# x11th.week     840.935794
# x12th.week     831.050808
# x13th.week     865.009161
# x14th.week     927.507978
# x15th.week     989.878018
# x16th.week    1011.985509
# x17th.week    1088.974688
# x18th.week    1095.217158
# x19th.week    1083.497863
# x20th.week    1074.373851
# x21st.week     403.042840
# x22nd.week     438.267769
# x23rd.week     325.610677
# x24th.week     336.865784
# x25th.week     341.851108
# x26th.week     356.500000
# x27th.week     376.087990
# x28th.week     252.416667
# x29th.week     220.627500
#                  ...
# x36th.week     171.580247
# x37th.week     221.876543
# x38th.week     140.984375
# x39th.week     292.687500
# ...

# %%
#checking types
#df.dtypes

# %%
#converting columsn to appropriate types
df['date.entered'] = pd.to_datetime(df['date.entered'])
df['date.peaked'] = pd.to_datetime(df['date.peaked'])

# %%
df.dtypes
# Out:
# year                        int64
# artist.inverted            object
# track                      object
# time                       object
# genre                      object
# date.entered       datetime64[ns]
# date.peaked        datetime64[ns]
# x1st.week                   int64
# x2nd.week                 float64
# x3rd.week                 float64
# x4th.week                 float64
# x5th.week                 float64
# x6th.week                 float64
# x7th.week                 float64
# x8th.week                 float64
# x9th.week                 float64
# x10th.week                float64
# x11th.week                float64
# x12th.week                float64
# x13th.week                float64
# x14th.week                float64
# x15th.week                float64
# x16th.week                float64
# x17th.week                float64
# x18th.week                float64
# x19th.week                float64
# x20th.week                float64
# ...

# %% [markdown]
# pivot tables could help me visualize the data better and look into relationships between certain columns and rows
